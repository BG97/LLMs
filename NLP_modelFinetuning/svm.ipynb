# %%
# imports

import os
import math
import json
import random
from dotenv import load_dotenv
from huggingface_hub import login
from items import Item
import matplotlib.pyplot as plt
import numpy as np
import pickle
from collections import Counter

# %%
# More imports for our traditional machine learning

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
# NLP related imports

from sklearn.feature_extraction.text import CountVectorizer
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

# %%
# Finally, more imports for more advanced machine learning

from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor

# %%
# Constants - used for printing to stdout in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %%
with open('train.pkl', 'rb') as file:
    train = pickle.load(file)

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
# Remind ourselves the training prompt

print(train[0].prompt)
# Out:
# How much does this cost to the nearest dollar?
#
# Delphi FG0166 Fuel Pump Module
# Delphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7
#
# Price is $227.00

# %%
class Tester:

    def __init__(self, predictor, title=None, data=test, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"
    
    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint)
        truth = datapoint.price
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint.title if len(datapoint.title) <= 40 else datapoint.title[:40]+"..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function):
        cls(function).run()

# %%
prices = np.array([float(item.price) for item in train])
documents = [item.test_prompt() for item in train]

# %%
# The amazing word2vec model, implemented in gensim NLP library

np.random.seed(42)

# Preprocess the documents
processed_docs = [simple_preprocess(doc) for doc in documents]

# Train Word2Vec model
w2v_model = Word2Vec(sentences=processed_docs, vector_size=400, window=5, min_count=1, workers=8)

# %%
# This step of averaging vectors across the document is a weakness in our approach

def document_vector(doc):
    doc_words = simple_preprocess(doc)
    word_vectors = [w2v_model.wv[word] for word in doc_words if word in w2v_model.wv]
    return np.mean(word_vectors, axis=0) if word_vectors else np.zeros(w2v_model.vector_size)

# Create feature matrix
X_w2v = np.array([document_vector(doc) for doc in documents])

# %%
# Support Vector Machines

np.random.seed(42)
svr_regressor = LinearSVR()

svr_regressor.fit(X_w2v, prices)
# Out:
# LinearSVR()

# %%
def svr_pricer(item):
    np.random.seed(42)
    doc = item.test_prompt()
    doc_vector = document_vector(doc)
    return max(float(svr_regressor.predict([doc_vector])[0]),0)

# %%
Tester.test(svr_pricer)
# Out:
# 1: Guess: $239.98 Truth: $374.41 Error: $134.43 SLE: 0.20 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $169.35 Truth: $225.11 Error: $55.76 SLE: 0.08 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $125.09 Truth: $61.68 Error: $63.41 SLE: 0.49 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $289.29 Truth: $599.99 Error: $310.70 SLE: 0.53 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $80.01 Truth: $16.99 Error: $63.02 SLE: 2.26 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $0.00 Truth: $31.99 Error: $31.99 SLE: 12.22 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $248.49 Truth: $101.79 Error: $146.70 SLE: 0.79 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $178.66 Truth: $289.00 Error: $110.34 SLE: 0.23 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $289.73 Truth: $635.86 Error: $346.13 SLE: 0.61 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# 10: Guess: $106.87 Truth: $65.99 Error: $40.88 SLE: 0.23 Item: HOLDWILL 6 Pack LED Shop Light, 4FT 24W ...
# 11: Guess: $342.12 Truth: $254.21 Error: $87.91 SLE: 0.09 Item: Viking Horns V103C/1005ATK 3 Gallon Air ...
# 12: Guess: $270.38 Truth: $412.99 Error: $142.61 SLE: 0.18 Item: CURT 70110 Custom Tow Bar Base Plate Bra...
# 13: Guess: $108.60 Truth: $205.50 Error: $96.90 SLE: 0.40 Item: 10-Pack Solar HAMMERED BRONZE Finish Pos...
# 14: Guess: $174.05 Truth: $248.23 Error: $74.18 SLE: 0.12 Item: COSTWAY Electric Tumble Dryer, Sliver
# 15: Guess: $186.33 Truth: $399.00 Error: $212.67 SLE: 0.58 Item: FREE SIGNAL TV Transit 32" 12 Volt DC Po...
# 16: Guess: $253.46 Truth: $373.94 Error: $120.48 SLE: 0.15 Item: Bilstein 5100 Monotube Gas Shock Set com...
# 17: Guess: $231.69 Truth: $92.89 Error: $138.80 SLE: 0.82 Item: Sangean K-200 Multi-Function Upright AM/...
# 18: Guess: $69.30 Truth: $51.99 Error: $17.31 SLE: 0.08 Item: Charles Leonard Magnetic Lapboard Class ...
# 19: Guess: $252.05 Truth: $179.00 Error: $73.05 SLE: 0.12 Item: Gigabyte AMD Radeon HD 7870 2 GB GDDR5 D...
# 20: Guess: $45.58 Truth: $19.42 Error: $26.16 SLE: 0.68 Item: 3dRose LLC 8 x 8 x 0.25 Inches Bull Terr...
# 21: Guess: $274.33 Truth: $539.95 Error: $265.62 SLE: 0.46 Item: ROKINON 85mm F1.4 Auto Focus Full Frame ...
# 22: Guess: $183.21 Truth: $147.67 Error: $35.54 SLE: 0.05 Item: AUTOSAVER88 Headlight Assembly Compatibl...
# 23: Guess: $30.01 Truth: $24.99 Error: $5.02 SLE: 0.03 Item: ASI NAUTICAL 2.5 Inches Opera Glasses Bi...
# 24: Guess: $249.70 Truth: $149.00 Error: $100.70 SLE: 0.26 Item: Behringer TUBE OVERDRIVE TO100 Authentic...
# 25: Guess: $14.34 Truth: $16.99 Error: $2.65 SLE: 0.03 Item: Fun Express Insect Finger Puppets - 24 f...
# 26: Guess: $104.33 Truth: $7.99 Error: $96.34 SLE: 6.06 Item: WAFJAMF Roller Stamp Identity Theft Stam...
# 27: Guess: $136.82 Truth: $199.99 Error: $63.17 SLE: 0.14 Item: Capulina Tiffany Floor Lamp 2-Light 16" ...
# 28: Guess: $164.26 Truth: $251.45 Error: $87.19 SLE: 0.18 Item: Apple Watch Series 6 (GPS, 44mm) - Space...
# 29: Guess: $173.05 Truth: $231.62 Error: $58.57 SLE: 0.08 Item: ICON 01725 Tandem Axle Fender Skirt FS17...
# 30: Guess: $149.50 Truth: $135.00 Error: $14.50 SLE: 0.01 Item: SanDisk 128GB Ultra (10 Pack) MicroSD Cl...
# 31: Guess: $234.06 Truth: $356.62 Error: $122.56 SLE: 0.18 Item: Velvac 2020,L,C/Hr,W,E2003,102",Bk - 715...
# 32: Guess: $244.16 Truth: $257.99 Error: $13.83 SLE: 0.00 Item: TCMT Passenger Backrest Sissy Bar & Lugg...
# 33: Guess: $129.01 Truth: $27.99 Error: $101.02 SLE: 2.25 Item: Alnicov 63.5MM Brass Tremolo Block，Tremo...
# 34: Guess: $136.76 Truth: $171.20 Error: $34.44 SLE: 0.05 Item: Subaru Forester Outback Legacy OEM Engin...
# 35: Guess: $136.75 Truth: $225.00 Error: $88.25 SLE: 0.25 Item: Richmond Auto Upholstery - 2012 Dodge Ra...
# 36: Guess: $181.35 Truth: $105.00 Error: $76.35 SLE: 0.29 Item: AP-39 Automotive Paint Primer Grey 2K Ur...
# 37: Guess: $201.98 Truth: $299.99 Error: $98.01 SLE: 0.16 Item: Road Top Wireless Carplay Retrofit Kit D...
# 38: Guess: $431.33 Truth: $535.09 Error: $103.76 SLE: 0.05 Item: Gibson Performance Exhaust 5658 Aluminiz...
# 39: Guess: $12.33 Truth: $12.33 Error: $0.00 SLE: 0.00 Item: Bella Tunno Happy Links - Baby Montessor...
# 40: Guess: $167.87 Truth: $84.99 Error: $82.88 SLE: 0.46 Item: CANMORE H300 Handheld GPS Golf Device, S...
# 41: Guess: $70.67 Truth: $15.99 Error: $54.68 SLE: 2.07 Item: DCPOWER AC Adapter Compatible Replacemen...
# 42: Guess: $99.82 Truth: $62.44 Error: $37.38 SLE: 0.21 Item: Sharp, VX2128V, Commercial Desktop Calcu...
# 43: Guess: $137.77 Truth: $82.99 Error: $54.78 SLE: 0.25 Item: Melissa & Doug Lifelike Plush Stork Gian...
# 44: Guess: $232.41 Truth: $599.95 Error: $367.54 SLE: 0.89 Item: Sony SSCS8 2-Way 3-Driver Center Channel...
# 45: Guess: $289.95 Truth: $194.99 Error: $94.96 SLE: 0.16 Item: ASUS Chromebook CX1, 14" Full HD NanoEdg...
# 46: Guess: $229.34 Truth: $344.95 Error: $115.61 SLE: 0.17 Item: FiiO X7 32GB Hi-Res Lossless Music Playe...
# 47: Guess: $67.92 Truth: $37.99 Error: $29.93 SLE: 0.32 Item: TORRO Leather Case Compatible with iPhon...
# 48: Guess: $214.60 Truth: $224.35 Error: $9.75 SLE: 0.00 Item: Universal Air Conditioner KT 1031 A/C Co...
# 49: Guess: $309.40 Truth: $814.00 Error: $504.60 SLE: 0.93 Item: Street Series Stainless Performance Cat-...
# 50: Guess: $417.55 Truth: $439.88 Error: $22.33 SLE: 0.00 Item: Lenovo IdeaPad 3 14-inch Laptop, 14.0-in...
# 51: Guess: $279.11 Truth: $341.43 Error: $62.32 SLE: 0.04 Item: Access Bed Covers TonnoSport 22050219 - ...
# 52: Guess: $154.82 Truth: $46.78 Error: $108.04 SLE: 1.40 Item: G.I. JOE Hasbro 3 3/4" Wave 5 Action Fig...
# 53: Guess: $120.41 Truth: $171.44 Error: $51.03 SLE: 0.12 Item: T&S Brass B-0232-BST Double Pantry Fauce...
# 54: Guess: $184.84 Truth: $458.00 Error: $273.16 SLE: 0.82 Item: ZTUOAUMA Fuel Injection Pump 3090942 309...
# 55: Guess: $210.59 Truth: $130.75 Error: $79.84 SLE: 0.22 Item: 2AP18AA#ABA Hp Prime Graphing Calculator...
# 56: Guess: $131.81 Truth: $83.81 Error: $48.00 SLE: 0.20 Item: Lowrance 000-0119-83 Nmea 2000 25' Exten...
# 57: Guess: $139.66 Truth: $386.39 Error: $246.73 SLE: 1.03 Item: Jeep Genuine Accessories 82213051 Hood L...
# 58: Guess: $155.20 Truth: $169.00 Error: $13.80 SLE: 0.01 Item: GODOX CB-06 Hard Carrying Case with Whee...
# 59: Guess: $77.79 Truth: $17.95 Error: $59.84 SLE: 2.03 Item: Au-Tomotive Gold, INC. Ford Black Valet ...
# 60: Guess: $129.44 Truth: $269.00 Error: $139.56 SLE: 0.53 Item: Snailfly Black Roof Rack Rail + Cross Ba...
# 61: Guess: $91.32 Truth: $77.77 Error: $13.55 SLE: 0.03 Item: KING SHA Anti Glare LED Track Lighting H...
# 62: Guess: $179.08 Truth: $88.99 Error: $90.09 SLE: 0.48 Item: APS Compatible with Chevy Silverado 1500...
# 63: Guess: $306.15 Truth: $364.41 Error: $58.26 SLE: 0.03 Item: Wilwood Engineering 14011291R Brake Cali...
# 64: Guess: $167.36 Truth: $127.03 Error: $40.33 SLE: 0.07 Item: ACDelco Gold 336-1925A Starter, Remanufa...
# 65: Guess: $270.86 Truth: $778.95 Error: $508.09 SLE: 1.11 Item: UWS EC10783 69-Inch Matte Black Heavy-Wa...
# 66: Guess: $461.04 Truth: $206.66 Error: $254.38 SLE: 0.64 Item: Dell Latitude E5440 14in Business Laptop...
# 67: Guess: $127.12 Truth: $35.94 Error: $91.18 SLE: 1.55 Item: (Plug and Play) Spare Tire Brake Light W...
# 68: Guess: $161.42 Truth: $149.00 Error: $12.42 SLE: 0.01 Item: The Ultimate Roadside Rescue Assistant
# 69: Guess: $219.17 Truth: $251.98 Error: $32.81 SLE: 0.02 Item: Brand New 18" x 8.5" Replacement Wheel f...
# 70: Guess: $193.74 Truth: $160.00 Error: $33.74 SLE: 0.04 Item: Headlight Headlamp LH Left & RH Right Pa...
# 71: Guess: $175.61 Truth: $39.99 Error: $135.62 SLE: 2.13 Item: Lilo And Stitch Deluxe Oversize Print La...
# 72: Guess: $209.87 Truth: $362.41 Error: $152.54 SLE: 0.30 Item: AC Compressor & A/C Clutch For Hyundai A...
# 73: Guess: $127.20 Truth: $344.00 Error: $216.80 SLE: 0.98 Item: House Of Troy PIN475-AB Pinnacle Collect...
# 74: Guess: $94.35 Truth: $25.09 Error: $69.26 SLE: 1.68 Item: Juno T29 WH Floating Electrical Feed Sin...
# 75: Guess: $79.56 Truth: $175.95 Error: $96.39 SLE: 0.62 Item: Sherman GO-PARTS - for 2013-2016 Toyota ...
# 76: Guess: $246.32 Truth: $132.64 Error: $113.68 SLE: 0.38 Item: Roland RPU-3 Electronic Keyboard Pedal o...
# 77: Guess: $280.77 Truth: $422.99 Error: $142.22 SLE: 0.17 Item: Rockland VMI14 12,000 Pound 12 Volt DC E...
# 78: Guess: $240.95 Truth: $146.48 Error: $94.47 SLE: 0.25 Item: Max Advanced Brakes Elite XDS Front Cros...
# 79: Guess: $132.37 Truth: $156.83 Error: $24.46 SLE: 0.03 Item: Quality-Built 11030 Premium Quality Alte...
# 80: Guess: $160.63 Truth: $251.99 Error: $91.36 SLE: 0.20 Item: Lucida LG-510 Student Classical Guitar, ...
# 81: Guess: $198.06 Truth: $940.33 Error: $742.27 SLE: 2.41 Item: Longacre 52-79800 Aluminum Turn Plates
# 82: Guess: $154.42 Truth: $52.99 Error: $101.43 SLE: 1.12 Item: Motion Pro 08-0380 Adjustable Torque Wre...
# 83: Guess: $79.25 Truth: $219.95 Error: $140.70 SLE: 1.03 Item: Glyph Thunderbolt 3 NVMe Dock (0 GB)
# 84: Guess: $273.14 Truth: $441.03 Error: $167.89 SLE: 0.23 Item: TOYO Open Country MT Performance Radial ...
# 85: Guess: $243.32 Truth: $168.98 Error: $74.34 SLE: 0.13 Item: Razer Seiren X USB Streaming Microphone ...
# 86: Guess: $53.45 Truth: $2.49 Error: $50.96 SLE: 7.55 Item: Happy Birthday to Dad From Your Daughter...
# 87: Guess: $212.92 Truth: $98.62 Error: $114.30 SLE: 0.58 Item: Little Tikes My Real Jam First Concert S...
# 88: Guess: $153.45 Truth: $256.95 Error: $103.50 SLE: 0.26 Item: Studio M Peace and Harmony Art Pole Comm...
# 89: Guess: $120.04 Truth: $30.99 Error: $89.05 SLE: 1.77 Item: MyVolts 12V Power Supply Adaptor Compati...
# 90: Guess: $352.42 Truth: $569.84 Error: $217.42 SLE: 0.23 Item: Dell Latitude 7212 Rugged Extreme Tablet...
# 91: Guess: $106.48 Truth: $177.99 Error: $71.51 SLE: 0.26 Item: Covermates Contour Fit Car Cover - Light...
# 92: Guess: $311.77 Truth: $997.99 Error: $686.22 SLE: 1.35 Item: Westin 57-4025 Black HDX Grille Guard fi...
# 93: Guess: $238.48 Truth: $219.00 Error: $19.48 SLE: 0.01 Item: Fieldpiece JL2 Job Link Wireless App Tra...
# 94: Guess: $190.41 Truth: $225.55 Error: $35.14 SLE: 0.03 Item: hansgrohe Talis S Modern Premium Easy Cl...
# 95: Guess: $292.58 Truth: $495.95 Error: $203.37 SLE: 0.28 Item: G-Technology G-SPEED eS PRO High-Perform...
# 96: Guess: $225.05 Truth: $942.37 Error: $717.32 SLE: 2.04 Item: DreamLine SHDR-1960723L-01 Shower Door, ...
# 97: Guess: $87.63 Truth: $1.94 Error: $85.69 SLE: 11.60 Item: Sanctuary Square Backplate Finish: Oiled...
# 98: Guess: $105.27 Truth: $284.34 Error: $179.07 SLE: 0.98 Item: Pelican Protector 1750 Long Case - Multi...
# 99: Guess: $179.87 Truth: $171.90 Error: $7.97 SLE: 0.00 Item: Brock Replacement Driver and Passenger H...
# 100: Guess: $77.90 Truth: $144.99 Error: $67.09 SLE: 0.38 Item: Carlinkit Ai Box Mini, Android 11, Multi...
# 101: Guess: $246.38 Truth: $470.47 Error: $224.09 SLE: 0.42 Item: StarDot NetCamLIVE2 YouTube Live Stream ...
# 102: Guess: $149.63 Truth: $66.95 Error: $82.68 SLE: 0.63 Item: Atomic Compatible FILXXCAR0016 16x25x5 M...
# 103: Guess: $15.52 Truth: $117.00 Error: $101.48 SLE: 3.86 Item: Bandai Awakening of S. H. s.h.figuarts s...
# 104: Guess: $284.56 Truth: $172.14 Error: $112.42 SLE: 0.25 Item: Fit System 62135G Passenger Side Towing ...
# 105: Guess: $235.91 Truth: $392.74 Error: $156.83 SLE: 0.26 Item: Black Horse Black Aluminum Exceed Runnin...
# 106: Guess: $0.11 Truth: $16.99 Error: $16.88 SLE: 7.77 Item: Dearsun Twinkle Star Color Night Light P...
# 107: Guess: $13.99 Truth: $1.34 Error: $12.65 SLE: 3.45 Item: Pokemon - Gallade Spirit Link (83/108) -...
# 108: Guess: $216.63 Truth: $349.98 Error: $133.35 SLE: 0.23 Item: Ibanez GA34STCE-NT GIO Series Classical ...
# 109: Guess: $231.32 Truth: $370.71 Error: $139.39 SLE: 0.22 Item: Set 2 Heavy Duty 12-16.5 12x16.5 12 Ply ...
# 110: Guess: $142.26 Truth: $65.88 Error: $76.38 SLE: 0.58 Item: Hairpin Table Legs 28" Heavy Duty Hairpi...
# 111: Guess: $177.77 Truth: $229.99 Error: $52.22 SLE: 0.07 Item: Marada Racing Seat with Adjustable Slide...
# 112: Guess: $79.18 Truth: $9.14 Error: $70.04 SLE: 4.28 Item: Remington Industries 24UL1007STRWHI25 24...
# 113: Guess: $338.36 Truth: $199.00 Error: $139.36 SLE: 0.28 Item: Acer S3-391-6046 13.3-inch Ultrabook, In...
# 114: Guess: $224.44 Truth: $109.99 Error: $114.45 SLE: 0.50 Item: ICBEAMER 7" RGB LED Headlights Bulb Halo...
# 115: Guess: $278.81 Truth: $570.42 Error: $291.61 SLE: 0.51 Item: R1 Concepts Front Rear Brakes and Rotors...
# 116: Guess: $165.87 Truth: $279.99 Error: $114.12 SLE: 0.27 Item: Camplux 2.64 GPM Tankless , Outdoor Port...
# 117: Guess: $103.43 Truth: $30.99 Error: $72.44 SLE: 1.40 Item: KNOKLOCK 10 Pack 3.75 Inch(96mm) Kitchen...
# 118: Guess: $162.52 Truth: $31.99 Error: $130.53 SLE: 2.56 Item: Valley Enterprises Yaesu USB FTDI CT-62 ...
# 119: Guess: $15.28 Truth: $15.90 Error: $0.62 SLE: 0.00 Item: G9 LED Light Bulbs，8W，75W 100W replaceme...
# 120: Guess: $74.09 Truth: $45.99 Error: $28.10 SLE: 0.22 Item: ZCHAOZ 4 Lights Antique White Farmhouse ...
# 121: Guess: $169.36 Truth: $113.52 Error: $55.84 SLE: 0.16 Item: Honeywell TH8320R1003 Honeywell VisionPr...
# 122: Guess: $250.40 Truth: $516.99 Error: $266.59 SLE: 0.52 Item: Patriot Exhaust H8013-1 1-7/8" Clippster...
# 123: Guess: $182.67 Truth: $196.99 Error: $14.32 SLE: 0.01 Item: Fitrite Autopart New Front Left Driver S...
# 124: Guess: $0.00 Truth: $46.55 Error: $46.55 SLE: 14.91 Item: Technical Precision Replacement for GE G...
# 125: Guess: $252.60 Truth: $356.99 Error: $104.39 SLE: 0.12 Item: Covercraft Carhartt SeatSaver Front Row ...
# 126: Guess: $132.02 Truth: $319.95 Error: $187.93 SLE: 0.78 Item: Sennheiser SD Pro 2 (506008) - Double-Si...
# 127: Guess: $215.24 Truth: $96.06 Error: $119.18 SLE: 0.64 Item: Hitachi MAF0110 Mass Air Flow Sensor
# 128: Guess: $213.73 Truth: $190.99 Error: $22.74 SLE: 0.01 Item: AmScope SE305R-P-LED-PS36A 10X-30X LED C...
# 129: Guess: $148.09 Truth: $257.95 Error: $109.86 SLE: 0.30 Item: Front Left Driver Side Window Regulator ...
# 130: Guess: $130.65 Truth: $62.95 Error: $67.70 SLE: 0.52 Item: Premium Replica Hubcap Set, Fits Nissan ...
# 131: Guess: $18.19 Truth: $47.66 Error: $29.47 SLE: 0.87 Item: Excellerations Phonics Spelling Game for...
# 132: Guess: $216.28 Truth: $226.99 Error: $10.71 SLE: 0.00 Item: RC4WD BigDog Dual Axle Scale Car/Truck T...
# 133: Guess: $290.12 Truth: $359.95 Error: $69.83 SLE: 0.05 Item: Unknown Stage 2 Clutch Kit - Low Altitud...
# 134: Guess: $239.20 Truth: $78.40 Error: $160.80 SLE: 1.23 Item: 2002-2008 Dodge Ram 1500 Mopar 4X4 Emble...
# 135: Guess: $294.86 Truth: $172.77 Error: $122.09 SLE: 0.28 Item: Pro Comp Alloys Series 89 Wheel with Pol...
# 136: Guess: $201.47 Truth: $316.45 Error: $114.98 SLE: 0.20 Item: Detroit Axle - Front Rear Strut & Coil S...
# 137: Guess: $94.93 Truth: $87.99 Error: $6.94 SLE: 0.01 Item: ECCPP Rear Wheel Axle Replacement fit fo...
# 138: Guess: $278.78 Truth: $226.63 Error: $52.15 SLE: 0.04 Item: Dell Latitude E6520 Intel i7-2720QM 2.20...
# 139: Guess: $123.92 Truth: $31.49 Error: $92.43 SLE: 1.81 Item: F FIERCE CYCLE 251pcs Black Universal Mo...
# 140: Guess: $158.59 Truth: $196.00 Error: $37.41 SLE: 0.04 Item: Flash Furniture 4 Pk. HERCULES Series 88...
# 141: Guess: $139.47 Truth: $78.40 Error: $61.07 SLE: 0.33 Item: B&M 30287 Throttle Valve/Kickdown Cable,...
# 142: Guess: $198.78 Truth: $116.25 Error: $82.53 SLE: 0.28 Item: Gates TCK226 PowerGrip Premium Timing Be...
# 143: Guess: $244.07 Truth: $112.78 Error: $131.29 SLE: 0.59 Item: Monroe Shocks & Struts Quick-Strut 17149...
# 144: Guess: $122.81 Truth: $27.32 Error: $95.49 SLE: 2.18 Item: Feit Electric BPMR16/GU10/930CA/6 35W EQ...
# 145: Guess: $177.53 Truth: $145.91 Error: $31.62 SLE: 0.04 Item: Yellow Jacket 2806 Contractor Extension ...
# 146: Guess: $164.40 Truth: $171.09 Error: $6.69 SLE: 0.00 Item: Garage-Pro Tailgate SET Compatible with ...
# 147: Guess: $162.40 Truth: $167.95 Error: $5.55 SLE: 0.00 Item: 3M Perfect It Buffing and Polishing Kit ...
# 148: Guess: $68.05 Truth: $28.49 Error: $39.56 SLE: 0.72 Item: Chinese Style Dollhouse Model DIY Miniat...
# 149: Guess: $196.96 Truth: $122.23 Error: $74.73 SLE: 0.22 Item: Generic NRG Innovations SRK-161H Steerin...
# 150: Guess: $66.37 Truth: $32.99 Error: $33.38 SLE: 0.47 Item: Learning Resources Coding Critters Range...
# 151: Guess: $198.14 Truth: $71.20 Error: $126.94 SLE: 1.03 Item: Bosch Automotive 15463 Oxygen Sensor, OE...
# 152: Guess: $48.83 Truth: $112.75 Error: $63.92 SLE: 0.68 Item: Case of 24-2 Inch Blue Painters Tape - 6...
# 153: Guess: $128.47 Truth: $142.43 Error: $13.96 SLE: 0.01 Item: MOCA Engine Water Pump & Fan Clutch fit ...
# 154: Guess: $182.66 Truth: $398.99 Error: $216.33 SLE: 0.61 Item: SAREMAS Foot Step Bars for Hyundai Palis...
# 155: Guess: $296.78 Truth: $449.00 Error: $152.22 SLE: 0.17 Item: Gretsch G9210 Square Neck Boxcar Mahogan...
# 156: Guess: $228.77 Truth: $189.00 Error: $39.77 SLE: 0.04 Item: NikoMaku Mirror Dash Cam Front and Rear ...
# 157: Guess: $154.77 Truth: $120.91 Error: $33.86 SLE: 0.06 Item: Fenix HP25R v2.0 USB-C Rechargeable Head...
# 158: Guess: $294.44 Truth: $203.53 Error: $90.91 SLE: 0.14 Item: R&L Racing Heavy Duty Roll-Up Soft Tonne...
# 159: Guess: $227.63 Truth: $349.99 Error: $122.36 SLE: 0.18 Item: Garmin 010-02258-10 GPSMAP 64sx, Handhel...
# 160: Guess: $16.91 Truth: $34.35 Error: $17.44 SLE: 0.46 Item: Brown 5-7/8" X 8-1/2" X 3/16" Thick Heav...
# 161: Guess: $162.98 Truth: $384.99 Error: $222.01 SLE: 0.73 Item: GAOMON PD2200 Pen Display & 20 Pen Nibs ...
# 162: Guess: $200.63 Truth: $211.00 Error: $10.37 SLE: 0.00 Item: VXMOTOR for 97-03 Ford F150/F250 Lightdu...
# 163: Guess: $411.51 Truth: $129.00 Error: $282.51 SLE: 1.33 Item: HP EliteBook 2540p Intel Core i7-640LM X...
# 164: Guess: $123.69 Truth: $111.45 Error: $12.24 SLE: 0.01 Item: Green EPX Mixing Nozzles 100-Pack-fits 3...
# 165: Guess: $176.53 Truth: $81.12 Error: $95.41 SLE: 0.59 Item: Box Partners 6 1/4 x 3 1/8" 13 Pt. Manil...
# 166: Guess: $213.81 Truth: $457.08 Error: $243.27 SLE: 0.57 Item: Vixen Air 1/2" NPT Air Ride Suspension H...
# 167: Guess: $157.88 Truth: $49.49 Error: $108.39 SLE: 1.31 Item: Smart Floor Lamp, 2700-6500K+RGBPink Mul...
# 168: Guess: $88.74 Truth: $80.56 Error: $8.18 SLE: 0.01 Item: SOZG 324mm Wheelbase Body Shell RC Car B...
# 169: Guess: $242.34 Truth: $278.39 Error: $36.05 SLE: 0.02 Item: Mickey Thompson ET Street S/S Racing Rad...
# 170: Guess: $207.69 Truth: $364.50 Error: $156.81 SLE: 0.31 Item: Pirelli 275/40R20 106W XL RFT P0 PZ4-LUX...
# 171: Guess: $423.94 Truth: $378.99 Error: $44.95 SLE: 0.01 Item: Torklift C3212 Rear Tie Down
# 172: Guess: $220.97 Truth: $165.28 Error: $55.69 SLE: 0.08 Item: Cardone 78-4226 Remanufactured Ford Comp...
# 173: Guess: $172.11 Truth: $56.74 Error: $115.37 SLE: 1.21 Item: Kidde AccessPoint 001798 Supra TouchPoin...
# 174: Guess: $144.16 Truth: $307.95 Error: $163.79 SLE: 0.57 Item: 3M Protecta 3100414 Self Retracting Life...
# 175: Guess: $122.82 Truth: $38.00 Error: $84.82 SLE: 1.33 Item: Plantronics 89435-01 Wired Headset, Blac...
# 176: Guess: $173.82 Truth: $53.00 Error: $120.82 SLE: 1.38 Item: Logitech K750 Wireless Solar Keyboard fo...
# 177: Guess: $240.38 Truth: $498.00 Error: $257.62 SLE: 0.53 Item: Olympus PEN E-PL9 Body Only with 3-Inch ...
# 178: Guess: $161.57 Truth: $53.99 Error: $107.58 SLE: 1.17 Item: Beck/Arnley 051-6066 Hub & Bearing Assem...
# 179: Guess: $249.17 Truth: $350.00 Error: $100.83 SLE: 0.11 Item: Eibach Pro-Kit Performance Springs E10-6...
# 180: Guess: $160.54 Truth: $299.95 Error: $139.41 SLE: 0.39 Item: LEGO DC Batman 1989 Batwing 76161 Displa...
# 181: Guess: $215.35 Truth: $94.93 Error: $120.42 SLE: 0.66 Item: Kingston Brass KS3608PL Restoration 4-In...
# 182: Guess: $251.82 Truth: $379.00 Error: $127.18 SLE: 0.17 Item: Polk Vanishing Series 265-LS In-Wall 3-W...
# 183: Guess: $231.70 Truth: $299.95 Error: $68.25 SLE: 0.07 Item: Spec-D Tuning LED Projector Headlights G...
# 184: Guess: $60.84 Truth: $24.99 Error: $35.85 SLE: 0.75 Item: RICHMOND & FINCH Airpod Pro Case, Green ...
# 185: Guess: $178.13 Truth: $41.04 Error: $137.09 SLE: 2.10 Item: LFA Industries 43B-5A-33JT 1/16-1/2-1.5-...
# 186: Guess: $128.23 Truth: $327.90 Error: $199.67 SLE: 0.87 Item: SAUTVS LED Headlight Assembly for Slings...
# 187: Guess: $17.92 Truth: $10.99 Error: $6.93 SLE: 0.21 Item: 2 Pack Combo Womens Safety Glasses Impac...
# 188: Guess: $9.03 Truth: $14.99 Error: $5.96 SLE: 0.22 Item: Arepa - Venezuelan cuisine - Venezuela P...
# 189: Guess: $138.14 Truth: $84.95 Error: $53.19 SLE: 0.23 Item: Schlage Lock Company KS23D2300 Padlock, ...
# 190: Guess: $192.16 Truth: $111.00 Error: $81.16 SLE: 0.30 Item: Techni Mobili White Sit to Stand Mobile ...
# 191: Guess: $156.23 Truth: $123.73 Error: $32.50 SLE: 0.05 Item: Special Lite Products Contemporary Wall ...
# 192: Guess: $134.26 Truth: $557.38 Error: $423.12 SLE: 2.01 Item: Tascam DP-24SD 24-Track Digital Portastu...
# 193: Guess: $163.82 Truth: $95.55 Error: $68.27 SLE: 0.29 Item: Glow Lighting 636CC10SP Vista Crystal Fl...
# 194: Guess: $179.05 Truth: $154.00 Error: $25.05 SLE: 0.02 Item: Z3 Wind Deflector, Smoke Tint, Lexan, Wi...
# 195: Guess: $249.99 Truth: $198.99 Error: $51.00 SLE: 0.05 Item: Olympus E-20 5MP Digital Camera w/ 4x Op...
# 196: Guess: $174.77 Truth: $430.44 Error: $255.67 SLE: 0.81 Item: PHYNEDI 1:1000 World Trade Center (1973-...
# 197: Guess: $17.24 Truth: $45.67 Error: $28.43 SLE: 0.88 Item: YANGHUAN Unstable Unicorns Adventure Car...
# 198: Guess: $210.78 Truth: $249.00 Error: $38.22 SLE: 0.03 Item: Interlogix NX-1820E NetworX Touch Screen...
# 199: Guess: $111.37 Truth: $42.99 Error: $68.38 SLE: 0.88 Item: Steering Damper,Universal Motorcycle Han...
# 200: Guess: $132.71 Truth: $181.33 Error: $48.62 SLE: 0.10 Item: Amprobe TIC 410A Hot Stick Attachment
# 201: Guess: $32.30 Truth: $6.03 Error: $26.27 SLE: 2.42 Item: MyCableMart 3.5mm Plug/Jack, 4 Conductor...
# 202: Guess: $78.80 Truth: $29.99 Error: $48.81 SLE: 0.89 Item: OtterBox + Pop Symmetry Series Case for ...
# 203: Guess: $416.47 Truth: $899.00 Error: $482.53 SLE: 0.59 Item: Dell XPS X8700-1572BLK Desktop ( Intel C...
# 204: Guess: $214.34 Truth: $399.99 Error: $185.65 SLE: 0.39 Item: Franklin Iron Works Sperry Industrial Br...
# 205: Guess: $119.21 Truth: $4.66 Error: $114.55 SLE: 9.34 Item: Avery Legal Dividers, Standard Collated ...
# 206: Guess: $234.96 Truth: $261.41 Error: $26.45 SLE: 0.01 Item: Moen 8346 Commercial Posi-Temp Pressure ...
# 207: Guess: $248.39 Truth: $136.97 Error: $111.42 SLE: 0.35 Item: Carlisle Versa Trail ATR All Terrain Rad...
# 208: Guess: $141.18 Truth: $79.00 Error: $62.18 SLE: 0.33 Item: SUNWAYFOTO 44mm Tripod Ball Head Arca Co...
# 209: Guess: $198.71 Truth: $444.99 Error: $246.28 SLE: 0.65 Item: NanoBeam AC NBE-5AC-Gen2-US 4 Units 5GHz...
# 210: Guess: $239.00 Truth: $411.94 Error: $172.94 SLE: 0.29 Item: WULF 4" Front 2" Rear Leveling Lift Kit ...
# 211: Guess: $143.55 Truth: $148.40 Error: $4.85 SLE: 0.00 Item: Alera ALEVABFMC Valencia Series Mobile B...
# 212: Guess: $25.14 Truth: $244.99 Error: $219.85 SLE: 5.03 Item: YU-GI-OH! Ignition Assault Booster Box
# 213: Guess: $150.41 Truth: $86.50 Error: $63.91 SLE: 0.30 Item: 48" x 36" Extra-Large Framed Magnetic Bl...
# 214: Guess: $358.44 Truth: $297.95 Error: $60.49 SLE: 0.03 Item: Dell Latitude D620 Renewed Notebook PC
# 215: Guess: $518.43 Truth: $399.99 Error: $118.44 SLE: 0.07 Item: acer Aspire 5 Laptop, AMD Ryzen 3 5300U ...
# 216: Guess: $241.32 Truth: $599.00 Error: $357.68 SLE: 0.82 Item: Elk 31080/6RC-GRN 30 by 6-Inch Viva 6-Li...
# 217: Guess: $154.46 Truth: $105.99 Error: $48.47 SLE: 0.14 Item: Barbie Top Model Doll
# 218: Guess: $235.62 Truth: $689.00 Error: $453.38 SLE: 1.15 Item: Danby Designer 20-In. Electric Range wit...
# 219: Guess: $194.17 Truth: $404.99 Error: $210.82 SLE: 0.54 Item: FixtureDisplays® Metal Truss Podium Doub...
# 220: Guess: $176.70 Truth: $207.76 Error: $31.06 SLE: 0.03 Item: ACDelco 13597235 GM Original Equipment A...
# 221: Guess: $270.37 Truth: $171.82 Error: $98.55 SLE: 0.20 Item: EBC S1KF1135 Stage-1 Premium Street Brak...
# 222: Guess: $271.68 Truth: $293.24 Error: $21.56 SLE: 0.01 Item: FXR Men's Boost FX Jacket (Black/Orange/...
# 223: Guess: $255.93 Truth: $374.95 Error: $119.02 SLE: 0.14 Item: SuperATV Scratch Resistant 3-in-1 Flip W...
# 224: Guess: $89.28 Truth: $111.99 Error: $22.71 SLE: 0.05 Item: SBU 3 Layer All Weather Mini Van Car Cov...
# 225: Guess: $7.90 Truth: $42.99 Error: $35.09 SLE: 2.55 Item: 2 Pack Outdoor Brochure Holder Advertisi...
# 226: Guess: $233.21 Truth: $116.71 Error: $116.50 SLE: 0.47 Item: Monroe Shocks & Struts Quick-Strut 17158...
# 227: Guess: $214.69 Truth: $118.61 Error: $96.08 SLE: 0.35 Item: Elements of Design Magellan EB235AL Thre...
# 228: Guess: $200.21 Truth: $147.12 Error: $53.09 SLE: 0.09 Item: GM Genuine Parts 15-62961 Air Conditioni...
# 229: Guess: $108.20 Truth: $119.99 Error: $11.79 SLE: 0.01 Item: Baseus 17-in-1 USB C Docking Station to ...
# 230: Guess: $127.97 Truth: $369.98 Error: $242.01 SLE: 1.12 Item: Whitehall™ Personalized Whitehall Capito...
# 231: Guess: $219.22 Truth: $315.55 Error: $96.33 SLE: 0.13 Item: Pro Circuit Works Pipe PY05250 for 02-19...
# 232: Guess: $266.02 Truth: $190.99 Error: $75.03 SLE: 0.11 Item: HYANKA 15 "1200W Professional DJ Speaker...
# 233: Guess: $56.76 Truth: $155.00 Error: $98.24 SLE: 0.99 Item: Bluetooth X6BT Card Reader Writer Encode...
# 234: Guess: $270.05 Truth: $349.99 Error: $79.94 SLE: 0.07 Item: AIRAID Cold Air Intake System by K&N: In...
# 235: Guess: $178.34 Truth: $249.99 Error: $71.65 SLE: 0.11 Item: Bostingner Shower Faucets Sets Complete,...
# 236: Guess: $139.36 Truth: $42.99 Error: $96.37 SLE: 1.35 Item: PIT66 Front Bumper Turn Signal Lights, C...
# 237: Guess: $81.06 Truth: $17.99 Error: $63.07 SLE: 2.14 Item: Caseology Bumpy Compatible with Google P...
# 238: Guess: $184.13 Truth: $425.00 Error: $240.87 SLE: 0.69 Item: Fleck 2510 Timer Mechanical Filter Contr...
# 239: Guess: $285.69 Truth: $249.99 Error: $35.70 SLE: 0.02 Item: Haloview MC7108 Wireless RV Backup Camer...
# 240: Guess: $55.62 Truth: $138.23 Error: $82.61 SLE: 0.81 Item: Schmidt Spiele - Manhattan
# 241: Guess: $240.96 Truth: $414.99 Error: $174.03 SLE: 0.29 Item: Corsa 14333 Tip Kit (Ford Mustang GT)
# 242: Guess: $192.39 Truth: $168.28 Error: $24.11 SLE: 0.02 Item: Hoshizaki FM116A Fan Motor Kit 1
# 243: Guess: $171.45 Truth: $199.99 Error: $28.54 SLE: 0.02 Item: BAINUO Antler Chandelier Lighting,6 Ligh...
# 244: Guess: $210.88 Truth: $126.70 Error: $84.18 SLE: 0.26 Item: DNA MOTORING HL-OH-FEXP06-SM-AM Smoke Le...
# 245: Guess: $70.36 Truth: $5.91 Error: $64.45 SLE: 5.45 Item: Wera Stainless 3840/1 TS 2.5mm Hex Inser...
# 246: Guess: $152.10 Truth: $193.06 Error: $40.96 SLE: 0.06 Item: Celestron - PowerSeeker 127EQ Telescope ...
# 247: Guess: $263.84 Truth: $249.99 Error: $13.85 SLE: 0.00 Item: NHOPEEW 10.1inch Android Car Radio Carpl...
# 248: Guess: $161.08 Truth: $64.12 Error: $96.96 SLE: 0.83 Item: Other Harmonica (Suzuki-2Timer24- A)
# 249: Guess: $259.93 Truth: $114.99 Error: $144.94 SLE: 0.66 Item: Harley Air Filter Venturi Intake Air Cle...
# 250: Guess: $109.26 Truth: $926.00 Error: $816.74 SLE: 4.53 Item: Elite Screens Edge Free Ambient Light Re...
