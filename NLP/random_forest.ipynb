# %%
# imports

import os
import math
import json
import random
from dotenv import load_dotenv
from huggingface_hub import login
from items import Item
import matplotlib.pyplot as plt
import numpy as np
import pickle
from collections import Counter

# %%
# More imports for our traditional machine learning

import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
# NLP related imports

from sklearn.feature_extraction.text import CountVectorizer
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess

# %%
# Finally, more imports for more advanced machine learning

from sklearn.svm import LinearSVR
from sklearn.ensemble import RandomForestRegressor

# %%
# Constants - used for printing to stdout in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %%
with open('train.pkl', 'rb') as file:
    train = pickle.load(file)

with open('test.pkl', 'rb') as file:
    test = pickle.load(file)

# %%
# Remind ourselves the training prompt

print(train[0].prompt)
# Out:
# How much does this cost to the nearest dollar?
#
# Delphi FG0166 Fuel Pump Module
# Delphi brings 80 years of OE Heritage into each Delphi pump, ensuring quality and fitment for each Delphi part. Part is validated, tested and matched to the right vehicle application Delphi brings 80 years of OE Heritage into each Delphi assembly, ensuring quality and fitment for each Delphi part Always be sure to check and clean fuel tank to avoid unnecessary returns Rigorous OE-testing ensures the pump can withstand extreme temperatures Brand Delphi, Fit Type Vehicle Specific Fit, Dimensions LxWxH 19.7 x 7.7 x 5.1 inches, Weight 2.2 Pounds, Auto Part Position Unknown, Operation Mode Mechanical, Manufacturer Delphi, Model FUEL PUMP, Dimensions 19.7
#
# Price is $227.00

# %%
class Tester:

    def __init__(self, predictor, title=None, data=test, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"
    
    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint)
        truth = datapoint.price
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint.title if len(datapoint.title) <= 40 else datapoint.title[:40]+"..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function):
        cls(function).run()

# %%
prices = np.array([float(item.price) for item in train])
documents = [item.test_prompt() for item in train]

# %%
# The amazing word2vec model, implemented in gensim NLP library

np.random.seed(42)

# Preprocess the documents
processed_docs = [simple_preprocess(doc) for doc in documents]

# Train Word2Vec model
w2v_model = Word2Vec(sentences=processed_docs, vector_size=400, window=5, min_count=1, workers=8)

# %%
# This step of averaging vectors across the document is a weakness in our approach

def document_vector(doc):
    doc_words = simple_preprocess(doc)
    word_vectors = [w2v_model.wv[word] for word in doc_words if word in w2v_model.wv]
    return np.mean(word_vectors, axis=0) if word_vectors else np.zeros(w2v_model.vector_size)

# Create feature matrix
X_w2v = np.array([document_vector(doc) for doc in documents])

# %%
#Random forest

rf_model = RandomForestRegressor(n_estimators=100, random_state=42, n_jobs=8)
rf_model.fit(X_w2v, prices)
# Out:
# RandomForestRegressor(n_jobs=8, random_state=42)

# %%
def random_forest_pricer(item):
    doc = item.test_prompt()
    doc_vector = document_vector(doc)
    return max(0, rf_model.predict([doc_vector])[0])

# %%
Tester.test(random_forest_pricer)
# Out:
# 1: Guess: $325.12 Truth: $374.41 Error: $49.29 SLE: 0.02 Item: OEM AC Compressor w/A/C Repair Kit For F...
# 2: Guess: $182.77 Truth: $225.11 Error: $42.34 SLE: 0.04 Item: Motorcraft YB3125 Fan Clutch
# 3: Guess: $176.33 Truth: $61.68 Error: $114.65 SLE: 1.08 Item: Dorman 603-159 Front Washer Fluid Reserv...
# 4: Guess: $429.38 Truth: $599.99 Error: $170.61 SLE: 0.11 Item: HP Premium 17.3-inch HD Plus Touchscreen...
# 5: Guess: $104.57 Truth: $16.99 Error: $87.58 SLE: 3.13 Item: 5-Position Super Switch Pickup Selector ...
# 6: Guess: $88.61 Truth: $31.99 Error: $56.62 SLE: 1.00 Item: Horror Bookmarks, Resin Horror Bookmarks...
# 7: Guess: $247.73 Truth: $101.79 Error: $145.94 SLE: 0.78 Item: SK6241 - Stinger 4 Gauge 6000 Series Pow...
# 8: Guess: $284.01 Truth: $289.00 Error: $4.99 SLE: 0.00 Item: Godox ML60Bi LED Light Kit, Handheld LED...
# 9: Guess: $290.91 Truth: $635.86 Error: $344.95 SLE: 0.61 Item: Randall RG75DG3PLUS G3 Plus 100-Watt Com...
# 10: Guess: $168.40 Truth: $65.99 Error: $102.41 SLE: 0.86 Item: HOLDWILL 6 Pack LED Shop Light, 4FT 24W ...
# 11: Guess: $367.19 Truth: $254.21 Error: $112.98 SLE: 0.13 Item: Viking Horns V103C/1005ATK 3 Gallon Air ...
# 12: Guess: $358.79 Truth: $412.99 Error: $54.20 SLE: 0.02 Item: CURT 70110 Custom Tow Bar Base Plate Bra...
# 13: Guess: $183.34 Truth: $205.50 Error: $22.16 SLE: 0.01 Item: 10-Pack Solar HAMMERED BRONZE Finish Pos...
# 14: Guess: $182.21 Truth: $248.23 Error: $66.02 SLE: 0.09 Item: COSTWAY Electric Tumble Dryer, Sliver
# 15: Guess: $299.99 Truth: $399.00 Error: $99.01 SLE: 0.08 Item: FREE SIGNAL TV Transit 32" 12 Volt DC Po...
# 16: Guess: $375.76 Truth: $373.94 Error: $1.82 SLE: 0.00 Item: Bilstein 5100 Monotube Gas Shock Set com...
# 17: Guess: $325.60 Truth: $92.89 Error: $232.71 SLE: 1.55 Item: Sangean K-200 Multi-Function Upright AM/...
# 18: Guess: $98.82 Truth: $51.99 Error: $46.83 SLE: 0.40 Item: Charles Leonard Magnetic Lapboard Class ...
# 19: Guess: $296.96 Truth: $179.00 Error: $117.96 SLE: 0.25 Item: Gigabyte AMD Radeon HD 7870 2 GB GDDR5 D...
# 20: Guess: $33.33 Truth: $19.42 Error: $13.91 SLE: 0.27 Item: 3dRose LLC 8 x 8 x 0.25 Inches Bull Terr...
# 21: Guess: $463.21 Truth: $539.95 Error: $76.74 SLE: 0.02 Item: ROKINON 85mm F1.4 Auto Focus Full Frame ...
# 22: Guess: $172.89 Truth: $147.67 Error: $25.22 SLE: 0.02 Item: AUTOSAVER88 Headlight Assembly Compatibl...
# 23: Guess: $69.62 Truth: $24.99 Error: $44.63 SLE: 1.00 Item: ASI NAUTICAL 2.5 Inches Opera Glasses Bi...
# 24: Guess: $367.27 Truth: $149.00 Error: $218.27 SLE: 0.81 Item: Behringer TUBE OVERDRIVE TO100 Authentic...
# 25: Guess: $29.20 Truth: $16.99 Error: $12.21 SLE: 0.27 Item: Fun Express Insect Finger Puppets - 24 f...
# 26: Guess: $165.24 Truth: $7.99 Error: $157.25 SLE: 8.51 Item: WAFJAMF Roller Stamp Identity Theft Stam...
# 27: Guess: $168.70 Truth: $199.99 Error: $31.29 SLE: 0.03 Item: Capulina Tiffany Floor Lamp 2-Light 16" ...
# 28: Guess: $225.89 Truth: $251.45 Error: $25.56 SLE: 0.01 Item: Apple Watch Series 6 (GPS, 44mm) - Space...
# 29: Guess: $240.19 Truth: $231.62 Error: $8.57 SLE: 0.00 Item: ICON 01725 Tandem Axle Fender Skirt FS17...
# 30: Guess: $168.06 Truth: $135.00 Error: $33.06 SLE: 0.05 Item: SanDisk 128GB Ultra (10 Pack) MicroSD Cl...
# 31: Guess: $298.61 Truth: $356.62 Error: $58.01 SLE: 0.03 Item: Velvac 2020,L,C/Hr,W,E2003,102",Bk - 715...
# 32: Guess: $290.59 Truth: $257.99 Error: $32.60 SLE: 0.01 Item: TCMT Passenger Backrest Sissy Bar & Lugg...
# 33: Guess: $178.40 Truth: $27.99 Error: $150.41 SLE: 3.32 Item: Alnicov 63.5MM Brass Tremolo Block，Tremo...
# 34: Guess: $203.62 Truth: $171.20 Error: $32.42 SLE: 0.03 Item: Subaru Forester Outback Legacy OEM Engin...
# 35: Guess: $220.60 Truth: $225.00 Error: $4.40 SLE: 0.00 Item: Richmond Auto Upholstery - 2012 Dodge Ra...
# 36: Guess: $184.42 Truth: $105.00 Error: $79.42 SLE: 0.31 Item: AP-39 Automotive Paint Primer Grey 2K Ur...
# 37: Guess: $220.96 Truth: $299.99 Error: $79.03 SLE: 0.09 Item: Road Top Wireless Carplay Retrofit Kit D...
# 38: Guess: $705.25 Truth: $535.09 Error: $170.16 SLE: 0.08 Item: Gibson Performance Exhaust 5658 Aluminiz...
# 39: Guess: $51.87 Truth: $12.33 Error: $39.54 SLE: 1.90 Item: Bella Tunno Happy Links - Baby Montessor...
# 40: Guess: $187.80 Truth: $84.99 Error: $102.81 SLE: 0.62 Item: CANMORE H300 Handheld GPS Golf Device, S...
# 41: Guess: $69.85 Truth: $15.99 Error: $53.86 SLE: 2.04 Item: DCPOWER AC Adapter Compatible Replacemen...
# 42: Guess: $203.51 Truth: $62.44 Error: $141.07 SLE: 1.37 Item: Sharp, VX2128V, Commercial Desktop Calcu...
# 43: Guess: $207.88 Truth: $82.99 Error: $124.89 SLE: 0.83 Item: Melissa & Doug Lifelike Plush Stork Gian...
# 44: Guess: $341.60 Truth: $599.95 Error: $258.35 SLE: 0.32 Item: Sony SSCS8 2-Way 3-Driver Center Channel...
# 45: Guess: $245.79 Truth: $194.99 Error: $50.80 SLE: 0.05 Item: ASUS Chromebook CX1, 14" Full HD NanoEdg...
# 46: Guess: $309.90 Truth: $344.95 Error: $35.05 SLE: 0.01 Item: FiiO X7 32GB Hi-Res Lossless Music Playe...
# 47: Guess: $49.39 Truth: $37.99 Error: $11.40 SLE: 0.07 Item: TORRO Leather Case Compatible with iPhon...
# 48: Guess: $238.75 Truth: $224.35 Error: $14.40 SLE: 0.00 Item: Universal Air Conditioner KT 1031 A/C Co...
# 49: Guess: $430.04 Truth: $814.00 Error: $383.96 SLE: 0.41 Item: Street Series Stainless Performance Cat-...
# 50: Guess: $511.64 Truth: $439.88 Error: $71.76 SLE: 0.02 Item: Lenovo IdeaPad 3 14-inch Laptop, 14.0-in...
# 51: Guess: $422.50 Truth: $341.43 Error: $81.07 SLE: 0.05 Item: Access Bed Covers TonnoSport 22050219 - ...
# 52: Guess: $206.87 Truth: $46.78 Error: $160.09 SLE: 2.16 Item: G.I. JOE Hasbro 3 3/4" Wave 5 Action Fig...
# 53: Guess: $306.78 Truth: $171.44 Error: $135.34 SLE: 0.34 Item: T&S Brass B-0232-BST Double Pantry Fauce...
# 54: Guess: $192.77 Truth: $458.00 Error: $265.23 SLE: 0.74 Item: ZTUOAUMA Fuel Injection Pump 3090942 309...
# 55: Guess: $245.41 Truth: $130.75 Error: $114.66 SLE: 0.39 Item: 2AP18AA#ABA Hp Prime Graphing Calculator...
# 56: Guess: $199.99 Truth: $83.81 Error: $116.18 SLE: 0.74 Item: Lowrance 000-0119-83 Nmea 2000 25' Exten...
# 57: Guess: $175.25 Truth: $386.39 Error: $211.14 SLE: 0.62 Item: Jeep Genuine Accessories 82213051 Hood L...
# 58: Guess: $248.15 Truth: $169.00 Error: $79.15 SLE: 0.15 Item: GODOX CB-06 Hard Carrying Case with Whee...
# 59: Guess: $169.52 Truth: $17.95 Error: $151.57 SLE: 4.83 Item: Au-Tomotive Gold, INC. Ford Black Valet ...
# 60: Guess: $198.15 Truth: $269.00 Error: $70.85 SLE: 0.09 Item: Snailfly Black Roof Rack Rail + Cross Ba...
# 61: Guess: $145.86 Truth: $77.77 Error: $68.09 SLE: 0.39 Item: KING SHA Anti Glare LED Track Lighting H...
# 62: Guess: $99.18 Truth: $88.99 Error: $10.19 SLE: 0.01 Item: APS Compatible with Chevy Silverado 1500...
# 63: Guess: $289.66 Truth: $364.41 Error: $74.75 SLE: 0.05 Item: Wilwood Engineering 14011291R Brake Cali...
# 64: Guess: $149.23 Truth: $127.03 Error: $22.20 SLE: 0.03 Item: ACDelco Gold 336-1925A Starter, Remanufa...
# 65: Guess: $702.94 Truth: $778.95 Error: $76.01 SLE: 0.01 Item: UWS EC10783 69-Inch Matte Black Heavy-Wa...
# 66: Guess: $343.50 Truth: $206.66 Error: $136.84 SLE: 0.26 Item: Dell Latitude E5440 14in Business Laptop...
# 67: Guess: $208.74 Truth: $35.94 Error: $172.80 SLE: 3.02 Item: (Plug and Play) Spare Tire Brake Light W...
# 68: Guess: $202.33 Truth: $149.00 Error: $53.33 SLE: 0.09 Item: The Ultimate Roadside Rescue Assistant
# 69: Guess: $249.42 Truth: $251.98 Error: $2.56 SLE: 0.00 Item: Brand New 18" x 8.5" Replacement Wheel f...
# 70: Guess: $229.42 Truth: $160.00 Error: $69.42 SLE: 0.13 Item: Headlight Headlamp LH Left & RH Right Pa...
# 71: Guess: $188.36 Truth: $39.99 Error: $148.37 SLE: 2.34 Item: Lilo And Stitch Deluxe Oversize Print La...
# 72: Guess: $289.51 Truth: $362.41 Error: $72.90 SLE: 0.05 Item: AC Compressor & A/C Clutch For Hyundai A...
# 73: Guess: $289.47 Truth: $344.00 Error: $54.53 SLE: 0.03 Item: House Of Troy PIN475-AB Pinnacle Collect...
# 74: Guess: $141.02 Truth: $25.09 Error: $115.93 SLE: 2.87 Item: Juno T29 WH Floating Electrical Feed Sin...
# 75: Guess: $233.55 Truth: $175.95 Error: $57.60 SLE: 0.08 Item: Sherman GO-PARTS - for 2013-2016 Toyota ...
# 76: Guess: $321.67 Truth: $132.64 Error: $189.03 SLE: 0.78 Item: Roland RPU-3 Electronic Keyboard Pedal o...
# 77: Guess: $272.44 Truth: $422.99 Error: $150.55 SLE: 0.19 Item: Rockland VMI14 12,000 Pound 12 Volt DC E...
# 78: Guess: $167.75 Truth: $146.48 Error: $21.27 SLE: 0.02 Item: Max Advanced Brakes Elite XDS Front Cros...
# 79: Guess: $176.21 Truth: $156.83 Error: $19.38 SLE: 0.01 Item: Quality-Built 11030 Premium Quality Alte...
# 80: Guess: $293.86 Truth: $251.99 Error: $41.87 SLE: 0.02 Item: Lucida LG-510 Student Classical Guitar, ...
# 81: Guess: $202.61 Truth: $940.33 Error: $737.72 SLE: 2.34 Item: Longacre 52-79800 Aluminum Turn Plates
# 82: Guess: $206.13 Truth: $52.99 Error: $153.14 SLE: 1.81 Item: Motion Pro 08-0380 Adjustable Torque Wre...
# 83: Guess: $125.48 Truth: $219.95 Error: $94.47 SLE: 0.31 Item: Glyph Thunderbolt 3 NVMe Dock (0 GB)
# 84: Guess: $324.69 Truth: $441.03 Error: $116.34 SLE: 0.09 Item: TOYO Open Country MT Performance Radial ...
# 85: Guess: $240.45 Truth: $168.98 Error: $71.47 SLE: 0.12 Item: Razer Seiren X USB Streaming Microphone ...
# 86: Guess: $110.85 Truth: $2.49 Error: $108.36 SLE: 12.02 Item: Happy Birthday to Dad From Your Daughter...
# 87: Guess: $232.02 Truth: $98.62 Error: $133.40 SLE: 0.72 Item: Little Tikes My Real Jam First Concert S...
# 88: Guess: $118.80 Truth: $256.95 Error: $138.15 SLE: 0.59 Item: Studio M Peace and Harmony Art Pole Comm...
# 89: Guess: $140.07 Truth: $30.99 Error: $109.08 SLE: 2.20 Item: MyVolts 12V Power Supply Adaptor Compati...
# 90: Guess: $377.83 Truth: $569.84 Error: $192.01 SLE: 0.17 Item: Dell Latitude 7212 Rugged Extreme Tablet...
# 91: Guess: $167.78 Truth: $177.99 Error: $10.21 SLE: 0.00 Item: Covermates Contour Fit Car Cover - Light...
# 92: Guess: $791.71 Truth: $997.99 Error: $206.28 SLE: 0.05 Item: Westin 57-4025 Black HDX Grille Guard fi...
# 93: Guess: $247.90 Truth: $219.00 Error: $28.90 SLE: 0.02 Item: Fieldpiece JL2 Job Link Wireless App Tra...
# 94: Guess: $294.22 Truth: $225.55 Error: $68.67 SLE: 0.07 Item: hansgrohe Talis S Modern Premium Easy Cl...
# 95: Guess: $284.22 Truth: $495.95 Error: $211.73 SLE: 0.31 Item: G-Technology G-SPEED eS PRO High-Perform...
# 96: Guess: $748.44 Truth: $942.37 Error: $193.93 SLE: 0.05 Item: DreamLine SHDR-1960723L-01 Shower Door, ...
# 97: Guess: $188.73 Truth: $1.94 Error: $186.79 SLE: 17.37 Item: Sanctuary Square Backplate Finish: Oiled...
# 98: Guess: $167.29 Truth: $284.34 Error: $117.05 SLE: 0.28 Item: Pelican Protector 1750 Long Case - Multi...
# 99: Guess: $210.37 Truth: $171.90 Error: $38.47 SLE: 0.04 Item: Brock Replacement Driver and Passenger H...
# 100: Guess: $125.82 Truth: $144.99 Error: $19.17 SLE: 0.02 Item: Carlinkit Ai Box Mini, Android 11, Multi...
# 101: Guess: $278.58 Truth: $470.47 Error: $191.89 SLE: 0.27 Item: StarDot NetCamLIVE2 YouTube Live Stream ...
# 102: Guess: $315.20 Truth: $66.95 Error: $248.25 SLE: 2.36 Item: Atomic Compatible FILXXCAR0016 16x25x5 M...
# 103: Guess: $217.33 Truth: $117.00 Error: $100.33 SLE: 0.38 Item: Bandai Awakening of S. H. s.h.figuarts s...
# 104: Guess: $333.64 Truth: $172.14 Error: $161.50 SLE: 0.43 Item: Fit System 62135G Passenger Side Towing ...
# 105: Guess: $326.93 Truth: $392.74 Error: $65.81 SLE: 0.03 Item: Black Horse Black Aluminum Exceed Runnin...
# 106: Guess: $47.75 Truth: $16.99 Error: $30.76 SLE: 0.99 Item: Dearsun Twinkle Star Color Night Light P...
# 107: Guess: $8.11 Truth: $1.34 Error: $6.77 SLE: 1.85 Item: Pokemon - Gallade Spirit Link (83/108) -...
# 108: Guess: $412.02 Truth: $349.98 Error: $62.04 SLE: 0.03 Item: Ibanez GA34STCE-NT GIO Series Classical ...
# 109: Guess: $358.62 Truth: $370.71 Error: $12.09 SLE: 0.00 Item: Set 2 Heavy Duty 12-16.5 12x16.5 12 Ply ...
# 110: Guess: $132.07 Truth: $65.88 Error: $66.19 SLE: 0.47 Item: Hairpin Table Legs 28" Heavy Duty Hairpi...
# 111: Guess: $183.94 Truth: $229.99 Error: $46.05 SLE: 0.05 Item: Marada Racing Seat with Adjustable Slide...
# 112: Guess: $147.09 Truth: $9.14 Error: $137.95 SLE: 7.19 Item: Remington Industries 24UL1007STRWHI25 24...
# 113: Guess: $576.39 Truth: $199.00 Error: $377.39 SLE: 1.12 Item: Acer S3-391-6046 13.3-inch Ultrabook, In...
# 114: Guess: $233.28 Truth: $109.99 Error: $123.29 SLE: 0.56 Item: ICBEAMER 7" RGB LED Headlights Bulb Halo...
# 115: Guess: $376.65 Truth: $570.42 Error: $193.77 SLE: 0.17 Item: R1 Concepts Front Rear Brakes and Rotors...
# 116: Guess: $370.51 Truth: $279.99 Error: $90.52 SLE: 0.08 Item: Camplux 2.64 GPM Tankless , Outdoor Port...
# 117: Guess: $59.15 Truth: $30.99 Error: $28.16 SLE: 0.40 Item: KNOKLOCK 10 Pack 3.75 Inch(96mm) Kitchen...
# 118: Guess: $157.56 Truth: $31.99 Error: $125.57 SLE: 2.46 Item: Valley Enterprises Yaesu USB FTDI CT-62 ...
# 119: Guess: $66.95 Truth: $15.90 Error: $51.05 SLE: 1.94 Item: G9 LED Light Bulbs，8W，75W 100W replaceme...
# 120: Guess: $192.44 Truth: $45.99 Error: $146.45 SLE: 2.00 Item: ZCHAOZ 4 Lights Antique White Farmhouse ...
# 121: Guess: $212.63 Truth: $113.52 Error: $99.11 SLE: 0.39 Item: Honeywell TH8320R1003 Honeywell VisionPr...
# 122: Guess: $279.70 Truth: $516.99 Error: $237.29 SLE: 0.38 Item: Patriot Exhaust H8013-1 1-7/8" Clippster...
# 123: Guess: $238.60 Truth: $196.99 Error: $41.61 SLE: 0.04 Item: Fitrite Autopart New Front Left Driver S...
# 124: Guess: $96.83 Truth: $46.55 Error: $50.28 SLE: 0.52 Item: Technical Precision Replacement for GE G...
# 125: Guess: $289.75 Truth: $356.99 Error: $67.24 SLE: 0.04 Item: Covercraft Carhartt SeatSaver Front Row ...
# 126: Guess: $206.55 Truth: $319.95 Error: $113.40 SLE: 0.19 Item: Sennheiser SD Pro 2 (506008) - Double-Si...
# 127: Guess: $151.20 Truth: $96.06 Error: $55.14 SLE: 0.20 Item: Hitachi MAF0110 Mass Air Flow Sensor
# 128: Guess: $217.92 Truth: $190.99 Error: $26.93 SLE: 0.02 Item: AmScope SE305R-P-LED-PS36A 10X-30X LED C...
# 129: Guess: $211.78 Truth: $257.95 Error: $46.17 SLE: 0.04 Item: Front Left Driver Side Window Regulator ...
# 130: Guess: $166.42 Truth: $62.95 Error: $103.47 SLE: 0.93 Item: Premium Replica Hubcap Set, Fits Nissan ...
# 131: Guess: $92.07 Truth: $47.66 Error: $44.41 SLE: 0.42 Item: Excellerations Phonics Spelling Game for...
# 132: Guess: $251.98 Truth: $226.99 Error: $24.99 SLE: 0.01 Item: RC4WD BigDog Dual Axle Scale Car/Truck T...
# 133: Guess: $284.92 Truth: $359.95 Error: $75.03 SLE: 0.05 Item: Unknown Stage 2 Clutch Kit - Low Altitud...
# 134: Guess: $238.37 Truth: $78.40 Error: $159.97 SLE: 1.22 Item: 2002-2008 Dodge Ram 1500 Mopar 4X4 Emble...
# 135: Guess: $200.74 Truth: $172.77 Error: $27.97 SLE: 0.02 Item: Pro Comp Alloys Series 89 Wheel with Pol...
# 136: Guess: $310.54 Truth: $316.45 Error: $5.91 SLE: 0.00 Item: Detroit Axle - Front Rear Strut & Coil S...
# 137: Guess: $202.76 Truth: $87.99 Error: $114.77 SLE: 0.69 Item: ECCPP Rear Wheel Axle Replacement fit fo...
# 138: Guess: $311.92 Truth: $226.63 Error: $85.29 SLE: 0.10 Item: Dell Latitude E6520 Intel i7-2720QM 2.20...
# 139: Guess: $149.21 Truth: $31.49 Error: $117.72 SLE: 2.34 Item: F FIERCE CYCLE 251pcs Black Universal Mo...
# 140: Guess: $226.11 Truth: $196.00 Error: $30.11 SLE: 0.02 Item: Flash Furniture 4 Pk. HERCULES Series 88...
# 141: Guess: $185.68 Truth: $78.40 Error: $107.28 SLE: 0.73 Item: B&M 30287 Throttle Valve/Kickdown Cable,...
# 142: Guess: $128.54 Truth: $116.25 Error: $12.29 SLE: 0.01 Item: Gates TCK226 PowerGrip Premium Timing Be...
# 143: Guess: $122.12 Truth: $112.78 Error: $9.34 SLE: 0.01 Item: Monroe Shocks & Struts Quick-Strut 17149...
# 144: Guess: $92.00 Truth: $27.32 Error: $64.68 SLE: 1.41 Item: Feit Electric BPMR16/GU10/930CA/6 35W EQ...
# 145: Guess: $110.04 Truth: $145.91 Error: $35.87 SLE: 0.08 Item: Yellow Jacket 2806 Contractor Extension ...
# 146: Guess: $230.55 Truth: $171.09 Error: $59.46 SLE: 0.09 Item: Garage-Pro Tailgate SET Compatible with ...
# 147: Guess: $176.93 Truth: $167.95 Error: $8.98 SLE: 0.00 Item: 3M Perfect It Buffing and Polishing Kit ...
# 148: Guess: $76.05 Truth: $28.49 Error: $47.56 SLE: 0.92 Item: Chinese Style Dollhouse Model DIY Miniat...
# 149: Guess: $213.73 Truth: $122.23 Error: $91.50 SLE: 0.31 Item: Generic NRG Innovations SRK-161H Steerin...
# 150: Guess: $69.27 Truth: $32.99 Error: $36.28 SLE: 0.53 Item: Learning Resources Coding Critters Range...
# 151: Guess: $165.43 Truth: $71.20 Error: $94.23 SLE: 0.70 Item: Bosch Automotive 15463 Oxygen Sensor, OE...
# 152: Guess: $78.87 Truth: $112.75 Error: $33.88 SLE: 0.13 Item: Case of 24-2 Inch Blue Painters Tape - 6...
# 153: Guess: $142.66 Truth: $142.43 Error: $0.23 SLE: 0.00 Item: MOCA Engine Water Pump & Fan Clutch fit ...
# 154: Guess: $273.87 Truth: $398.99 Error: $125.12 SLE: 0.14 Item: SAREMAS Foot Step Bars for Hyundai Palis...
# 155: Guess: $471.88 Truth: $449.00 Error: $22.88 SLE: 0.00 Item: Gretsch G9210 Square Neck Boxcar Mahogan...
# 156: Guess: $244.69 Truth: $189.00 Error: $55.69 SLE: 0.07 Item: NikoMaku Mirror Dash Cam Front and Rear ...
# 157: Guess: $211.90 Truth: $120.91 Error: $90.99 SLE: 0.31 Item: Fenix HP25R v2.0 USB-C Rechargeable Head...
# 158: Guess: $216.04 Truth: $203.53 Error: $12.51 SLE: 0.00 Item: R&L Racing Heavy Duty Roll-Up Soft Tonne...
# 159: Guess: $353.32 Truth: $349.99 Error: $3.33 SLE: 0.00 Item: Garmin 010-02258-10 GPSMAP 64sx, Handhel...
# 160: Guess: $109.30 Truth: $34.35 Error: $74.95 SLE: 1.29 Item: Brown 5-7/8" X 8-1/2" X 3/16" Thick Heav...
# 161: Guess: $298.75 Truth: $384.99 Error: $86.24 SLE: 0.06 Item: GAOMON PD2200 Pen Display & 20 Pen Nibs ...
# 162: Guess: $268.57 Truth: $211.00 Error: $57.57 SLE: 0.06 Item: VXMOTOR for 97-03 Ford F150/F250 Lightdu...
# 163: Guess: $414.62 Truth: $129.00 Error: $285.62 SLE: 1.35 Item: HP EliteBook 2540p Intel Core i7-640LM X...
# 164: Guess: $165.31 Truth: $111.45 Error: $53.86 SLE: 0.15 Item: Green EPX Mixing Nozzles 100-Pack-fits 3...
# 165: Guess: $244.41 Truth: $81.12 Error: $163.29 SLE: 1.20 Item: Box Partners 6 1/4 x 3 1/8" 13 Pt. Manil...
# 166: Guess: $402.16 Truth: $457.08 Error: $54.92 SLE: 0.02 Item: Vixen Air 1/2" NPT Air Ride Suspension H...
# 167: Guess: $128.17 Truth: $49.49 Error: $78.68 SLE: 0.88 Item: Smart Floor Lamp, 2700-6500K+RGBPink Mul...
# 168: Guess: $150.58 Truth: $80.56 Error: $70.02 SLE: 0.38 Item: SOZG 324mm Wheelbase Body Shell RC Car B...
# 169: Guess: $283.11 Truth: $278.39 Error: $4.72 SLE: 0.00 Item: Mickey Thompson ET Street S/S Racing Rad...
# 170: Guess: $217.15 Truth: $364.50 Error: $147.35 SLE: 0.27 Item: Pirelli 275/40R20 106W XL RFT P0 PZ4-LUX...
# 171: Guess: $296.12 Truth: $378.99 Error: $82.87 SLE: 0.06 Item: Torklift C3212 Rear Tie Down
# 172: Guess: $170.63 Truth: $165.28 Error: $5.35 SLE: 0.00 Item: Cardone 78-4226 Remanufactured Ford Comp...
# 173: Guess: $199.68 Truth: $56.74 Error: $142.94 SLE: 1.55 Item: Kidde AccessPoint 001798 Supra TouchPoin...
# 174: Guess: $165.33 Truth: $307.95 Error: $142.62 SLE: 0.38 Item: 3M Protecta 3100414 Self Retracting Life...
# 175: Guess: $197.93 Truth: $38.00 Error: $159.93 SLE: 2.65 Item: Plantronics 89435-01 Wired Headset, Blac...
# 176: Guess: $165.36 Truth: $53.00 Error: $112.36 SLE: 1.27 Item: Logitech K750 Wireless Solar Keyboard fo...
# 177: Guess: $342.28 Truth: $498.00 Error: $155.72 SLE: 0.14 Item: Olympus PEN E-PL9 Body Only with 3-Inch ...
# 178: Guess: $216.98 Truth: $53.99 Error: $162.99 SLE: 1.90 Item: Beck/Arnley 051-6066 Hub & Bearing Assem...
# 179: Guess: $316.72 Truth: $350.00 Error: $33.28 SLE: 0.01 Item: Eibach Pro-Kit Performance Springs E10-6...
# 180: Guess: $151.61 Truth: $299.95 Error: $148.34 SLE: 0.46 Item: LEGO DC Batman 1989 Batwing 76161 Displa...
# 181: Guess: $190.53 Truth: $94.93 Error: $95.60 SLE: 0.48 Item: Kingston Brass KS3608PL Restoration 4-In...
# 182: Guess: $431.23 Truth: $379.00 Error: $52.23 SLE: 0.02 Item: Polk Vanishing Series 265-LS In-Wall 3-W...
# 183: Guess: $247.18 Truth: $299.95 Error: $52.77 SLE: 0.04 Item: Spec-D Tuning LED Projector Headlights G...
# 184: Guess: $22.40 Truth: $24.99 Error: $2.59 SLE: 0.01 Item: RICHMOND & FINCH Airpod Pro Case, Green ...
# 185: Guess: $201.10 Truth: $41.04 Error: $160.06 SLE: 2.47 Item: LFA Industries 43B-5A-33JT 1/16-1/2-1.5-...
# 186: Guess: $155.26 Truth: $327.90 Error: $172.64 SLE: 0.55 Item: SAUTVS LED Headlight Assembly for Slings...
# 187: Guess: $133.50 Truth: $10.99 Error: $122.51 SLE: 5.84 Item: 2 Pack Combo Womens Safety Glasses Impac...
# 188: Guess: $41.91 Truth: $14.99 Error: $26.92 SLE: 0.97 Item: Arepa - Venezuelan cuisine - Venezuela P...
# 189: Guess: $206.97 Truth: $84.95 Error: $122.02 SLE: 0.78 Item: Schlage Lock Company KS23D2300 Padlock, ...
# 190: Guess: $246.52 Truth: $111.00 Error: $135.52 SLE: 0.63 Item: Techni Mobili White Sit to Stand Mobile ...
# 191: Guess: $235.44 Truth: $123.73 Error: $111.71 SLE: 0.41 Item: Special Lite Products Contemporary Wall ...
# 192: Guess: $319.81 Truth: $557.38 Error: $237.57 SLE: 0.31 Item: Tascam DP-24SD 24-Track Digital Portastu...
# 193: Guess: $192.59 Truth: $95.55 Error: $97.04 SLE: 0.48 Item: Glow Lighting 636CC10SP Vista Crystal Fl...
# 194: Guess: $160.48 Truth: $154.00 Error: $6.48 SLE: 0.00 Item: Z3 Wind Deflector, Smoke Tint, Lexan, Wi...
# 195: Guess: $330.86 Truth: $198.99 Error: $131.87 SLE: 0.26 Item: Olympus E-20 5MP Digital Camera w/ 4x Op...
# 196: Guess: $175.85 Truth: $430.44 Error: $254.59 SLE: 0.80 Item: PHYNEDI 1:1000 World Trade Center (1973-...
# 197: Guess: $114.23 Truth: $45.67 Error: $68.56 SLE: 0.82 Item: YANGHUAN Unstable Unicorns Adventure Car...
# 198: Guess: $358.72 Truth: $249.00 Error: $109.72 SLE: 0.13 Item: Interlogix NX-1820E NetworX Touch Screen...
# 199: Guess: $208.50 Truth: $42.99 Error: $165.51 SLE: 2.44 Item: Steering Damper,Universal Motorcycle Han...
# 200: Guess: $192.28 Truth: $181.33 Error: $10.95 SLE: 0.00 Item: Amprobe TIC 410A Hot Stick Attachment
# 201: Guess: $94.29 Truth: $6.03 Error: $88.26 SLE: 6.80 Item: MyCableMart 3.5mm Plug/Jack, 4 Conductor...
# 202: Guess: $40.49 Truth: $29.99 Error: $10.50 SLE: 0.09 Item: OtterBox + Pop Symmetry Series Case for ...
# 203: Guess: $479.54 Truth: $899.00 Error: $419.46 SLE: 0.39 Item: Dell XPS X8700-1572BLK Desktop ( Intel C...
# 204: Guess: $379.46 Truth: $399.99 Error: $20.53 SLE: 0.00 Item: Franklin Iron Works Sperry Industrial Br...
# 205: Guess: $80.68 Truth: $4.66 Error: $76.02 SLE: 7.13 Item: Avery Legal Dividers, Standard Collated ...
# 206: Guess: $233.76 Truth: $261.41 Error: $27.65 SLE: 0.01 Item: Moen 8346 Commercial Posi-Temp Pressure ...
# 207: Guess: $216.98 Truth: $136.97 Error: $80.01 SLE: 0.21 Item: Carlisle Versa Trail ATR All Terrain Rad...
# 208: Guess: $177.99 Truth: $79.00 Error: $98.99 SLE: 0.65 Item: SUNWAYFOTO 44mm Tripod Ball Head Arca Co...
# 209: Guess: $259.12 Truth: $444.99 Error: $185.87 SLE: 0.29 Item: NanoBeam AC NBE-5AC-Gen2-US 4 Units 5GHz...
# 210: Guess: $274.10 Truth: $411.94 Error: $137.84 SLE: 0.16 Item: WULF 4" Front 2" Rear Leveling Lift Kit ...
# 211: Guess: $194.09 Truth: $148.40 Error: $45.69 SLE: 0.07 Item: Alera ALEVABFMC Valencia Series Mobile B...
# 212: Guess: $126.86 Truth: $244.99 Error: $118.13 SLE: 0.43 Item: YU-GI-OH! Ignition Assault Booster Box
# 213: Guess: $158.57 Truth: $86.50 Error: $72.07 SLE: 0.36 Item: 48" x 36" Extra-Large Framed Magnetic Bl...
# 214: Guess: $200.53 Truth: $297.95 Error: $97.42 SLE: 0.16 Item: Dell Latitude D620 Renewed Notebook PC
# 215: Guess: $603.94 Truth: $399.99 Error: $203.95 SLE: 0.17 Item: acer Aspire 5 Laptop, AMD Ryzen 3 5300U ...
# 216: Guess: $324.86 Truth: $599.00 Error: $274.14 SLE: 0.37 Item: Elk 31080/6RC-GRN 30 by 6-Inch Viva 6-Li...
# 217: Guess: $170.44 Truth: $105.99 Error: $64.45 SLE: 0.22 Item: Barbie Top Model Doll
# 218: Guess: $311.12 Truth: $689.00 Error: $377.88 SLE: 0.63 Item: Danby Designer 20-In. Electric Range wit...
# 219: Guess: $331.35 Truth: $404.99 Error: $73.64 SLE: 0.04 Item: FixtureDisplays® Metal Truss Podium Doub...
# 220: Guess: $263.60 Truth: $207.76 Error: $55.84 SLE: 0.06 Item: ACDelco 13597235 GM Original Equipment A...
# 221: Guess: $193.56 Truth: $171.82 Error: $21.74 SLE: 0.01 Item: EBC S1KF1135 Stage-1 Premium Street Brak...
# 222: Guess: $279.60 Truth: $293.24 Error: $13.64 SLE: 0.00 Item: FXR Men's Boost FX Jacket (Black/Orange/...
# 223: Guess: $292.17 Truth: $374.95 Error: $82.78 SLE: 0.06 Item: SuperATV Scratch Resistant 3-in-1 Flip W...
# 224: Guess: $121.70 Truth: $111.99 Error: $9.71 SLE: 0.01 Item: SBU 3 Layer All Weather Mini Van Car Cov...
# 225: Guess: $35.23 Truth: $42.99 Error: $7.76 SLE: 0.04 Item: 2 Pack Outdoor Brochure Holder Advertisi...
# 226: Guess: $125.04 Truth: $116.71 Error: $8.33 SLE: 0.00 Item: Monroe Shocks & Struts Quick-Strut 17158...
# 227: Guess: $229.36 Truth: $118.61 Error: $110.75 SLE: 0.43 Item: Elements of Design Magellan EB235AL Thre...
# 228: Guess: $185.03 Truth: $147.12 Error: $37.91 SLE: 0.05 Item: GM Genuine Parts 15-62961 Air Conditioni...
# 229: Guess: $192.92 Truth: $119.99 Error: $72.93 SLE: 0.22 Item: Baseus 17-in-1 USB C Docking Station to ...
# 230: Guess: $252.36 Truth: $369.98 Error: $117.62 SLE: 0.15 Item: Whitehall™ Personalized Whitehall Capito...
# 231: Guess: $245.86 Truth: $315.55 Error: $69.69 SLE: 0.06 Item: Pro Circuit Works Pipe PY05250 for 02-19...
# 232: Guess: $313.21 Truth: $190.99 Error: $122.22 SLE: 0.24 Item: HYANKA 15 "1200W Professional DJ Speaker...
# 233: Guess: $136.07 Truth: $155.00 Error: $18.93 SLE: 0.02 Item: Bluetooth X6BT Card Reader Writer Encode...
# 234: Guess: $348.10 Truth: $349.99 Error: $1.89 SLE: 0.00 Item: AIRAID Cold Air Intake System by K&N: In...
# 235: Guess: $213.04 Truth: $249.99 Error: $36.95 SLE: 0.03 Item: Bostingner Shower Faucets Sets Complete,...
# 236: Guess: $183.32 Truth: $42.99 Error: $140.33 SLE: 2.05 Item: PIT66 Front Bumper Turn Signal Lights, C...
# 237: Guess: $58.73 Truth: $17.99 Error: $40.74 SLE: 1.31 Item: Caseology Bumpy Compatible with Google P...
# 238: Guess: $288.51 Truth: $425.00 Error: $136.49 SLE: 0.15 Item: Fleck 2510 Timer Mechanical Filter Contr...
# 239: Guess: $277.20 Truth: $249.99 Error: $27.21 SLE: 0.01 Item: Haloview MC7108 Wireless RV Backup Camer...
# 240: Guess: $83.60 Truth: $138.23 Error: $54.63 SLE: 0.25 Item: Schmidt Spiele - Manhattan
# 241: Guess: $260.91 Truth: $414.99 Error: $154.08 SLE: 0.21 Item: Corsa 14333 Tip Kit (Ford Mustang GT)
# 242: Guess: $241.22 Truth: $168.28 Error: $72.94 SLE: 0.13 Item: Hoshizaki FM116A Fan Motor Kit 1
# 243: Guess: $191.89 Truth: $199.99 Error: $8.10 SLE: 0.00 Item: BAINUO Antler Chandelier Lighting,6 Ligh...
# 244: Guess: $213.65 Truth: $126.70 Error: $86.95 SLE: 0.27 Item: DNA MOTORING HL-OH-FEXP06-SM-AM Smoke Le...
# 245: Guess: $129.35 Truth: $5.91 Error: $123.44 SLE: 8.63 Item: Wera Stainless 3840/1 TS 2.5mm Hex Inser...
# 246: Guess: $173.73 Truth: $193.06 Error: $19.33 SLE: 0.01 Item: Celestron - PowerSeeker 127EQ Telescope ...
# 247: Guess: $300.52 Truth: $249.99 Error: $50.53 SLE: 0.03 Item: NHOPEEW 10.1inch Android Car Radio Carpl...
# 248: Guess: $225.81 Truth: $64.12 Error: $161.69 SLE: 1.56 Item: Other Harmonica (Suzuki-2Timer24- A)
# 249: Guess: $199.60 Truth: $114.99 Error: $84.61 SLE: 0.30 Item: Harley Air Filter Venturi Intake Air Cle...
# 250: Guess: $249.49 Truth: $926.00 Error: $676.51 SLE: 1.71 Item: Elite Screens Edge Free Ambient Light Re...
